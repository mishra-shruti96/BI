# %%
import pandas as pd
df = pd.read_csv("forestfires.csv")
df
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area  \
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# ..  .. ..   ...  ...   ...    ...    ...   ...   ...  ..   ...   ...    ...
# 512  4  3   aug  sun  81.6   56.7  665.6   1.9  27.8  32   2.7   0.0   6.44
# 513  2  4   aug  sun  81.6   56.7  665.6   1.9  21.9  71   5.8   0.0  54.29
# 514  7  4   aug  sun  81.6   56.7  665.6   1.9  21.2  70   6.7   0.0  11.16
# 515  1  4   aug  sat  94.4  146.0  614.7  11.3  25.6  42   4.0   0.0   0.00
# 516  6  3   nov  tue  79.5    3.0  106.7   1.1  11.8  31   4.5   0.0   0.00
#
#      fire
# 0       0
# 1       0
# 2       0
# ...

# %%
#showing correlation plot between different features in the dataset.

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix
import seaborn as sns
#Seaborn is a library for making statistical graphics in Python.
#It is built on top of matplotlib and closely integrated with pandas data structures.

df= pd.read_csv('forestfires.csv')
#data = pd.read_csv('forestfires.csv', usecols=['X','Y','month','day','FFMC','DMC','DC','ISI','temp','RH','wind','rain','area'])
names = ['X','Y','month','day','FFMC','DMC','DC','ISI','temp','RH','wind','rain','area','fire']
data=df[df.columns[0:15]]
corr=data.corr()
plt.subplots(figsize=(15,15))
sns.heatmap(corr,annot = True, vmin=-1, vmax=1, center= 0, cmap= 'coolwarm',square=True)

#scatter plot
scatter_matrix(data,figsize=[20,20])
plt.show()

# %%
# Box plot showing the variation in values for the different features of the dataset.
#data=df[df.columns[0:15]]
boxplot = df.boxplot(figsize=[10,10])

# %%
#Plot consisting of variation of FFMC with respect to ‘fire’ and is hued with respect to ‘fire’. The value of 0 for
#‘fire’ means there is no occurrence of forest fires and 1 represents the occurrence of forest fires.

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("forestfires.csv")
#N=df['fire'].count()
x = df['fire']
y = df['FFMC']
#colors = np.random.rand(N)

plt.scatter(x, y, c=colors, alpha=0.5)
plt.xlabel("fire")
plt.ylabel("FFMC ")
plt.xlabel("fire")
plt.ylabel("FFMC")
plt.show()

# %%
#Plot consisting of variation of DMC with respect to‘fire’ 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("forestfires.csv")
#N=df['fire'].count()
x = df['fire']
y = df['DMC']
#colors = np.random.rand(N)

plt.scatter(x, y, c=colors, alpha=0.5)
plt.xlabel("fire")
plt.ylabel("DMC ")
plt.xlabel("fire")
plt.ylabel("DMC")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
df=pd.read_csv("forestfires.csv")


print("variation of ISI with respect to‘fire’")
x = df['fire']
y = df['ISI']
plt.scatter(x, y, c=colors, alpha=0.5)
plt.xlabel("fire")
plt.ylabel("ISI")
plt.xlabel("fire")
plt.ylabel("ISI")
plt.show()


print("variation of RH with respect to‘fire’ ")
x = df['fire']
y = df['RH']

plt.scatter(x, y, c=colors, alpha=0.5)
plt.xlabel("fire")
plt.ylabel("RH ")
plt.xlabel("fire")
plt.ylabel("RH")
plt.show()


print("variation of temp with respect to ‘fire’ ")
x = df['fire']
y = df['temp']


plt.scatter(x, y, c=colors, alpha=0.5)
plt.xlabel("fire")
plt.ylabel("temp ")
plt.xlabel("fire")
plt.ylabel("temp")
plt.show()


print("variation of ‘wind’ with respect to ‘fire’ ")
x = df['fire']
y = df['wind']

plt.scatter(x, y, c=colors, alpha=0.5)
plt.xlabel("fire")
plt.ylabel("wind ")
plt.xlabel("fire")
plt.ylabel("wind")
plt.show()
# Out:
# variation of ISI with respect to‘fire’
# variation of RH with respect to‘fire’
# variation of temp with respect to ‘fire’
# variation of ‘wind’ with respect to ‘fire’

# %%
#Box plot representation of the variance of FFMC with respect to each month.
boxplot = df.boxplot(by='month',column=['FFMC'],figsize=[10,10])
